# %%
import pickle as pk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('4rcls/Adam/9_timesteps/acc_RCNN-96_9_time_30ep_1e-3_Adam.pkl','rb') as f:
    acc = pk.load(f)
with open('4rcls/Adam/9_timesteps/loss_RCNN-96_9_time_30ep_1e-3_Adam.pkl','rb') as f:
    loss = pk.load(f)

# %%
fig = plt.figure()
fig.suptitle('RCNN-96, 4 RCL blocks, 9 timestep, lr=1e-3 on Adam', fontsize=10)
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.plot(loss)
fig.savefig('loss.png')
